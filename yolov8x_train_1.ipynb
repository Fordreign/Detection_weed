# %%
pip install ultralytics

# %%
import numpy as np
from ultralytics import YOLO
import cv2
import torch

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
device
# Out:
# 'cuda'

# %%
model = YOLO('yolov8l.pt')

# %%
model.train(data='/kaggle/input/weed-det/WeedCrop.v1i.yolov5pytorch/data.yaml', epochs=100, imgsz=640, batch=16, device=device, seed=69)
# Out:
# Ultralytics YOLOv8.0.117 🚀 Python-3.10.10 torch-2.0.0 CUDA:0 (Tesla P100-PCIE-16GB, 16281MiB)
# ...
